# %% [markdown]
# # Project - Probability of default for credit card

# %%
import pandas as pd

# %%
df = pd.read_excel("default_of_credit_card_clients.xls", header = 1)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %% [markdown]
# First we have to understand features in this dataset

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.iloc[:,:6].head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE
# 0   1      20000    2          2         1   24
# 1   2     120000    2          2         2   26
# 2   3      90000    2          2         2   34
# 3   4      50000    2          2         1   37
# 4   5      50000    1          2         1   57

# %%
df.iloc[:,6:12].head()
# Out:
#    PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1
# 0      2      2     -1     -1     -2     -2       3913
# 1     -1      2      0      0      0      2       2682
# 2      0      0      0      0      0      0      29239
# 3      0      0      0      0      0      0      46990
# 4     -1      0     -1      0      0      0       8617

# %%
df.iloc[:,12:18].head()
# Out:
#    BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6
# 0       3913       3102        689          0          0          0
# 1       2682       1725       2682       3272       3455       3261
# 2      29239      14027      13559      14331      14948      15549
# 3      46990      48233      49291      28314      28959      29547
# 4       8617       5670      35835      20940      19146      19131

# %%
df.iloc[:,18:24].head()
# Out:
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0         0       689         0         0         0         0
# 1         0      1000      1000      1000         0      2000
# 2      1518      1500      1000      1000      1000      5000
# 3      2000      2019      1200      1100      1069      1000
# 4      2000     36681     10000      9000       689       679

# %%
df.iloc[:,24:].head()
# Out:
#    default payment next month
# 0                           1
# 1                           1
# 2                           0
# 3                           0
# 4                           0

# %% [markdown]
# ## Let's check quality of this dataset

# %%
print("Number of row with empty values")
df.isnull().sum().sum()
# Out:
# Number of row with empty values
# 0

# %%
print("Number of duplicated rows")
df.duplicated().any()
# Out:
# Number of duplicated rows
# False

# %%
print("Let's look at basic statistic for each column. Looking for some incoreect value - for example age = -2")
df.iloc[:,:12].describe()
# Out:
# Let's look at basic statistic for each column. Looking for some incoreect value - for example age = -2
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# ...

# %%
df.iloc[:,12:].describe()
# Out:
#            BILL_AMT1      BILL_AMT2     BILL_AMT3      BILL_AMT4  \
# count   30000.000000   30000.000000  3.000000e+04   30000.000000
# mean    51223.330900   49179.075167  4.701315e+04   43262.948967
# std     73635.860576   71173.768783  6.934939e+04   64332.856134
# min   -165580.000000  -69777.000000 -1.572640e+05 -170000.000000
# 25%      3558.750000    2984.750000  2.666250e+03    2326.750000
# 50%     22381.500000   21200.000000  2.008850e+04   19052.000000
# 75%     67091.000000   64006.250000  6.016475e+04   54506.000000
# max    964511.000000  983931.000000  1.664089e+06  891586.000000
#
#            BILL_AMT5      BILL_AMT6       PAY_AMT1      PAY_AMT2  \
# count   30000.000000   30000.000000   30000.000000  3.000000e+04
# mean    40311.400967   38871.760400    5663.580500  5.921163e+03
# std     60797.155770   59554.107537   16563.280354  2.304087e+04
# min    -81334.000000 -339603.000000       0.000000  0.000000e+00
# ...

# %% [markdown]
# Look at types of each variable.

# %%
df.dtypes
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
#Here can be a problem, because sometimes we can get incorrect value for dividing ints.
a = 2.0
b = 3
print(f"Type for a={type(a)}. Type for b={type(b)}")
# Out:
# Type for a=<class 'float'>. Type for b=<class 'int'>
